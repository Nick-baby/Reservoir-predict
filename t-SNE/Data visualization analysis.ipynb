# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats 
import os
currentPath = os.getcwd().replace('\\', '/')
source=pd.read_excel(currentPath+'/Source_data/por/N1-N2-N3.xlsx')
target=pd.read_csv(currentPath+'/target_data/Well logged data/A1.csv')

# %%
Label_source="Source"
label_target="A1"

# %%
from scipy.stats import *
plt.figure()
sns.distplot(source['GR'].values, kde=True,bins=50,color="#ef4026",kde_kws={"label":Label_source,'linestyle':"solid"})
sns.distplot(target["GR_1"].values, kde=True, bins=50, color="#0339f8",kde_kws={"label":label_target,'linestyle':"-."})
plt.legend(loc="upper right",fontsize=15)
plt.xticks(fontsize=23)
plt.yticks(fontsize=23)
plt.xlabel('GR',fontsize=23)
plt.ylabel("Density",fontsize=23)
plt.show()
# Out:
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(source['KTH'].values, kde=True,bins=50,color="#ef4026",kde_kws={"label":Label_source,'linestyle':"solid"})
sns.distplot(target["KTH_1"].values, kde=True, bins=50,color="#0339f8",kde_kws={"label":label_target,'linestyle':"-."})
plt.legend(loc="upper right",fontsize=15)
plt.xticks(fontsize=23)
plt.yticks(fontsize=23)
plt.xlabel('KTH',fontsize=23)
plt.ylabel("Density",fontsize=23)
plt.show()
# Out:
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(source['U'].values, kde=True,bins=50, color="#ef4026", kde_kws={"label":Label_source,'linestyle':"solid"})
sns.distplot(target["URAN_1"].values, kde=True, bins=50, color="#0339f8",kde_kws={"label":label_target,'linestyle':"-."})
plt.legend(loc="upper right",fontsize=15)
plt.xticks(fontsize=23)
plt.yticks(fontsize=23)
plt.xlabel('U',fontsize=23)
plt.ylabel("Density",fontsize=23)
plt.show()
# Out:
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(source['AC'].values, kde=True,bins=50, color="#ef4026",kde_kws={"label":Label_source,'linestyle':"solid"})
sns.distplot(target["AC_1"].values, kde=True, bins=50,color="#0339f8", kde_kws={"label":label_target,'linestyle':"-."})
plt.legend(loc="upper right",fontsize=15)
plt.xticks(fontsize=23)
plt.yticks(fontsize=23)
plt.xlabel('AC ',fontsize=23)
plt.ylabel("Density",fontsize=23)
plt.show()
# Out:
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(source['DEN'].values, norm_hist=True,kde=True,bins=50,color="#ef4026",kde_kws={"label":Label_source,'linestyle':"solid"})
sns.distplot(target["DEN_1"].values, norm_hist=True,kde=True,bins=50,color="#0339f8",kde_kws={"label":label_target,'linestyle':"-."})
plt.legend(loc="upper right",fontsize=15)
plt.xticks(fontsize=23)
plt.yticks(fontsize=23)
plt.xlabel('DEN',fontsize=23)
plt.ylabel("Density",fontsize=23)
plt.show()
# Out:
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.manifold import TSNE
tsne = TSNE(n_components=1, init='pca', random_state=0)
src = tsne.fit_transform(source.values[:,1:-1])
tar = tsne.fit_transform(target.values[:,1:-1])
sns.distplot(src, kde=True,bins=50,color="#ef4026",kde_kws={"label":"Source",'linestyle':"solid"} )
sns.distplot(tar, kde=True,bins=50,color="#0339f8",kde_kws={"label":"A1",'linestyle':"-."} )
plt.legend(loc="upper right",fontsize=15)
plt.xticks(fontsize=23)
plt.yticks(fontsize=23)
plt.ylabel("Density",fontsize=23,)
plt.xlabel("T-SNE Map Value",fontsize=23)
plt.show()
# Out:
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\conda_new\envs\pytorch\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
